# %%
# importing libraries
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = pd.read_csv("house_dataset_250.csv")

# %%
df.head(5)
# Out:
#    area  bedrooms  bathrooms  floors  parking  age  location_score     price
# 0  3219         1          1       3        2    7               4  12982816
# 1  3616         1          1       3        3    1               1  13914246
# 2  1495         2          2       3        1   22               9   8292398
# 3  1502         4          5       1        1   22               7   8633778
# 4  1738         2          2       2        0    2               7   8854414

# %%
df.tail(5)
# Out:
#      area  bedrooms  bathrooms  floors  parking  age  location_score     price
# 245   742         2          2       1        2   11               7   5551799
# 246   732         5          5       3        3   30               6   6202084
# 247  2418         1          1       3        2   12               6  10625227
# 248  1622         1          1       3        1   15               9   8482785
# 249  2900         1          2       2        3    6              10  13709449

# %%
df.shape
# Out:
# (250, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   area            250 non-null    int64
#  1   bedrooms        250 non-null    int64
#  2   bathrooms       250 non-null    int64
#  3   floors          250 non-null    int64
#  4   parking         250 non-null    int64
#  5   age             250 non-null    int64
#  6   location_score  250 non-null    int64
#  7   price           250 non-null    int64
# dtypes: int64(8)
# memory usage: 15.8 KB

# %%
df.describe()
# Out:
#              area    bedrooms   bathrooms      floors     parking         age  \
# count   250.00000  250.000000  250.000000  250.000000  250.000000  250.000000
# mean   2324.48800    3.460000    3.840000    2.092000    1.536000   15.028000
# std     977.44174    1.707649    1.680983    0.783576    1.094301    9.026246
# min     633.00000    1.000000    1.000000    1.000000    0.000000    0.000000
# 25%    1520.00000    2.000000    2.000000    1.000000    1.000000    7.000000
# 50%    2396.00000    3.000000    4.000000    2.000000    2.000000   15.000000
# 75%    3170.25000    5.000000    5.000000    3.000000    2.000000   23.000000
# max    3978.00000    6.000000    6.000000    3.000000    3.000000   30.000000
#
#        location_score         price
# count      250.000000  2.500000e+02
# mean         5.664000  1.122468e+07
# std          2.805457  3.615199e+06
# min          1.000000  2.943651e+06
# 25%          3.000000  8.313578e+06
# 50%          6.000000  1.128761e+07
# 75%          8.000000  1.427336e+07
# max         10.000000  1.852313e+07

# %%
# Checking missing values
df.isnull().sum()
# Out:
# area              0
# bedrooms          0
# bathrooms         0
# floors            0
# parking           0
# age               0
# location_score    0
# price             0
# dtype: int64

# %%
# check duplicate values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['area', 'bedrooms', 'bathrooms', 'floors', 'parking', 'age',
#        'location_score', 'price'],
#       dtype='object')

# %%
X = df.drop("price",axis=1)
Y = df["price"]

# %%
print(X.head())
# Out:
#    area  bedrooms  bathrooms  floors  parking  age  location_score
# 0  3219         1          1       3        2    7               4
# 1  3616         1          1       3        3    1               1
# 2  1495         2          2       3        1   22               9
# 3  1502         4          5       1        1   22               7
# 4  1738         2          2       2        0    2               7

# %%
print(Y.head())
# Out:
# 0    12982816
# 1    13914246
# 2     8292398
# 3     8633778
# 4     8854414
# Name: price, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(df["price"], bins=20)
plt.title("Distribution of House Prices")
plt.xlabel("Price")
plt.ylabel("Number of Houses")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(df["area"], df["price"])
plt.title("Area vs House Price")
plt.xlabel("Area (sq.ft)")
plt.ylabel("Price")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(df["bedrooms"], df["price"])
plt.title("Bedrooms vs House Price")
plt.xlabel("Bedrooms")
plt.ylabel("Price")
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), annot=True, cmap="Blues")
plt.title("Correlation Matrix")
plt.show()

# %%
#pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.9.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in c:\Users\star\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (2.3.3)
# Requirement already satisfied: scipy>=1.10.0 in c:\Users\star\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (1.16.3)
# Collecting joblib>=1.4.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: narwhals>=2.0.1 in c:\Users\star\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (2.15.0)
# Collecting threadpoolctl>=3.5.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.9.0-cp313-cp313-win_amd64.whl (8.2 MB)
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.2 MB 507.6 kB/s eta 0:00:16
#    --- ------------------------------------ 0.8/8.2 MB 683.0 kB/s eta 0:00:11
#    --- ------------------------------------ 0.8/8.2 MB 683.0 kB/s eta 0:00:11
#    --- ------------------------------------ 0.8/8.2 MB 683.0 kB/s eta 0:00:11
#    ----- ---------------------------------- 1.0/8.2 MB 607.3 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.0/8.2 MB 607.3 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.0/8.2 MB 607.3 kB/s eta 0:00:12
#    ------ --------------------------------- 1.3/8.2 MB 524.2 kB/s eta 0:00:14
#    ------ --------------------------------- 1.3/8.2 MB 524.2 kB/s eta 0:00:14
#    ------- -------------------------------- 1.6/8.2 MB 521.8 kB/s eta 0:00:13
#    ------- -------------------------------- 1.6/8.2 MB 521.8 kB/s eta 0:00:13
#    ------- -------------------------------- 1.6/8.2 MB 521.8 kB/s eta 0:00:13
#    ------- -------------------------------- 1.6/8.2 MB 521.8 kB/s eta 0:00:13
#    -------- ------------------------------- 1.8/8.2 MB 466.0 kB/s eta 0:00:14
#    -------- ------------------------------- 1.8/8.2 MB 466.0 kB/s eta 0:00:14
#    ---------- ----------------------------- 2.1/8.2 MB 490.8 kB/s eta 0:00:13
#    ------------ --------------------------- 2.6/8.2 MB 588.5 kB/s eta 0:00:10
#    -------------- ------------------------- 2.9/8.2 MB 632.5 kB/s eta 0:00:09
#    ---------------- ----------------------- 3.4/8.2 MB 699.0 kB/s eta 0:00:07
#    ----------------- ---------------------- 3.7/8.2 MB 732.1 kB/s eta 0:00:07
#    ------------------- -------------------- 3.9/8.2 MB 752.6 kB/s eta 0:00:06
#    --------------------- ------------------ 4.5/8.2 MB 824.4 kB/s eta 0:00:05
#    ------------------------ --------------- 5.0/8.2 MB 899.0 kB/s eta 0:00:04
#    -------------------------- ------------- 5.5/8.2 MB 960.6 kB/s eta 0:00:03
#    ----------------------------- ---------- 6.0/8.2 MB 1.0 MB/s eta 0:00:03
#    ------------------------------ --------- 6.3/8.2 MB 1.0 MB/s eta 0:00:02
#    --------------------------------- ------ 6.8/8.2 MB 1.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 7.3/8.2 MB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.2 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 1.2 MB/s  0:00:07
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
#
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    ---------------------------------------- 3/3 [scikit-learn]
#
# Successfully installed joblib-1.5.3 scikit-learn-1.9.0 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.model_selection import train_test_split

# %%
#Train test split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
print(X_train.shape )
print(X_test.shape)
# Out:
# (200, 7)
# (50, 7)

# %%
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (200,)
# (50,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
# Predict
y_pred = model.predict(X_test)

# %%
print(y_pred[:10])
# Out:
# [12095303.08964043  6820008.29609528 10009993.33224987  8111293.39257394
#  13741794.63342502  7679756.1292126  16716855.7837913   8702313.20712949
#   8451179.66082358 10487831.4132449 ]

# %%
# Checking model accuracy
from sklearn.metrics import r2_score

# %%
score = r2_score(Y_test,y_pred)
print("R2 Score:",score)
# Out:
# R2 Score: 0.9970250631827031

# %%
import joblib

# %%
#Save the model
joblib.dump(model, "model.pkl")
# Out:
# ['model.pkl']
